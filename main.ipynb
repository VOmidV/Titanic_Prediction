# %% [markdown]
# ### Importing Libraries that we need in this project

# %%
# libraries 
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input ,BatchNormalization,Conv1D,MaxPooling1D ,Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import AUC
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import tensorflow as tf
import tensorflow_decision_forests as tfdf

# %% [markdown]
# ### Reading the Train and Test CSV files

# %%
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# %%
# Checking out the train dataset
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Deleting .,()[] from Name culumn and also making two new Columns out of Ticket Columns

# %%
def prepering_data(df):
    df = df.copy()
    #name
    def normalize_name(x):
        return " ".join([v.strip(",()[].\"'") for v in x.split(" ")])
    #Ticket number
    def ticket_number(x):
        return x.split(" ")[-1]
    #Ticket lable
    def ticket_lable(x):
        items = x.split(' ')
        if len(items) == 1:
            return "NONE"
        return "_".join(items[0:-1])
    
    df["Name"] = df["Name"].apply(normalize_name)
    df["Ticket_number"] = df["Ticket"].apply(ticket_number)
    df["Ticket_item"] = df["Ticket"].apply(ticket_lable)                     
    return df

preprocessed_train_df = prepering_data(train_df)
preprocessed_test_df = prepering_data(test_df)

# %%
#Checkout Name, and two new columns(Ticket_number and Ticket_item)
preprocessed_train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                               Name     Sex   Age  SibSp  \
# 0                            Braund Mr Owen Harris    male  22.0      1
# 1  Cumings Mrs John Bradley Florence Briggs Thayer  female  38.0      1
# 2                             Heikkinen Miss Laina  female  26.0      0
# 3         Futrelle Mrs Jacques Heath Lily May Peel  female  35.0      1
# 4                           Allen Mr William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Ticket_number Ticket_item
# 0      0         A/5 21171   7.2500   NaN        S         21171         A/5
# 1      0          PC 17599  71.2833   C85        C         17599          PC
# 2      0  STON/O2. 3101282   7.9250   NaN        S       3101282    STON/O2.
# 3      0            113803  53.1000  C123        S        113803        NONE
# 4      0            373450   8.0500   NaN        S        373450        NONE

# %% [markdown]
# ### Droping out PassengerId and Ticket since they're not giving us any helpful informations. Also creating the features for out model

# %%
combine = [preprocessed_train_df, preprocessed_test_df]
Y = preprocessed_train_df['Survived']

for dataset in combine:
    dataset.drop(['PassengerId', 'Ticket'], axis=1, inplace=True)
features = list(preprocessed_train_df.columns)
features.remove('Survived')

# %%
print(features)
# Out:
# ['Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Cabin', 'Embarked', 'Ticket_number', 'Ticket_item']

# %%
# Helper function to tokenize the 'Name' column
def tokenize_names(features, labels=None):
    # Split full names into tokens (e.g., "Smith, Mr. John" → ["Smith,", "Mr.", "John"])
    features["Name"] =  tf.strings.split(features["Name"])
    return features, labels

# Convert preprocessed training and test dataframes to TensorFlow datasets
train_ds = tfdf.keras.pd_dataframe_to_tf_dataset(preprocessed_train_df,label="Survived").map(tokenize_names)
serving_ds = tfdf.keras.pd_dataframe_to_tf_dataset(preprocessed_test_df).map(tokenize_names)

# %% [markdown]
# ## Model

# %%
# Initialize variables to collect predictions
predictions = None
num_predictions = 0

# Train the same model multiple times with different random seeds
# This helps reduce model variance (like bagging) and gives a more stable final prediction
for i in range(200):
    model = tfdf.keras.GradientBoostedTreesModel(
        verbose=0,      # suppress logs
        features=[tfdf.keras.FeatureUsage(name=n) for n in features],
        exclude_non_specified_features=True,
        random_seed=i,      # different seed each time to diversify trees
        honest=True,        # ensure fair training by using out-of-bag samples
    )
    model.fit(train_ds)
    
    # Predict on the serving set
    sub_predictions = model.predict(serving_ds, verbose=0)[:,0]
    # Aggregate predictions across all runs
    if predictions is None:
        predictions = sub_predictions
    else:
        predictions += sub_predictions
    num_predictions += 1

# Average the predictions over all models
predictions/=num_predictions

# Prepare final Kaggle submission file
kaggle_predictions = pd.DataFrame({
        "PassengerId": test_df["PassengerId"],
        "Survived": (predictions >= 0.5).astype(int)
    })
# Out:
# W0000 00:00:1743111904.450256 18509509 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111904.450284 18509509 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111904.450286 18509509 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1743111904.640663 18509509 kernel.cc:782] Start Yggdrasil model training
# I0000 00:00:1743111904.640682 18509509 kernel.cc:783] Collect training examples
# I0000 00:00:1743111904.640686 18509509 kernel.cc:795] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# column_guides {
#   column_name_pattern: "^Pclass$"
# }
# column_guides {
#   column_name_pattern: "^Name$"
# }
# column_guides {
#   column_name_pattern: "^Sex$"
# }
# column_guides {
#   column_name_pattern: "^Age$"
# }
# column_guides {
#   column_name_pattern: "^SibSp$"
# }
# column_guides {
#   column_name_pattern: "^Parch$"
# }
# column_guides {
#   column_name_pattern: "^Fare$"
# }
# column_guides {
#   column_name_pattern: "^Cabin$"
# }
# column_guides {
#   column_name_pattern: "^Embarked$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_number$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_item$"
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: true
# detect_numerical_as_discretized_numerical: false
#
# I0000 00:00:1743111904.640832 18509509 kernel.cc:401] Number of batches: 1
# I0000 00:00:1743111904.640837 18509509 kernel.cc:402] Number of examples: 891
# I0000 00:00:1743111904.641153 18509509 data_spec_inference.cc:354] 147 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Cabin (0 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111904.641320 18509509 data_spec_inference.cc:354] 1441 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Name (85 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111904.641423 18509509 data_spec_inference.cc:354] 28 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_item (16 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111904.641511 18509509 data_spec_inference.cc:354] 671 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_number (8 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111904.641781 18509509 kernel.cc:802] Training dataset:
# Number of records: 891
# Number of columns: 12
#
# Number of columns by type:
# 	CATEGORICAL: 6 (50%)
# 	NUMERICAL: 5 (41.6667%)
# 	CATEGORICAL_SET: 1 (8.33333%)
#
# Columns:
#
# CATEGORICAL: 6 (50%)
# 	1: "Cabin" CATEGORICAL num-nas:687 (77.1044%) has-dict vocab-size:1 num-oods:204 (100%)
# 	2: "Embarked" CATEGORICAL num-nas:2 (0.224467%) has-dict vocab-size:4 zero-ood-items most-frequent:"S" 644 (72.4409%)
# 	7: "Sex" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"male" 577 (64.7587%)
# 	9: "Ticket_item" CATEGORICAL has-dict vocab-size:17 num-oods:46 (5.16274%) most-frequent:"NONE" 665 (74.6352%)
# 	10: "Ticket_number" CATEGORICAL has-dict vocab-size:9 num-oods:842 (94.5006%) most-frequent:"<OOD>" 842 (94.5006%)
# 	11: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 5 (41.6667%)
# 	0: "Age" NUMERICAL num-nas:177 (19.8653%) mean:29.6991 min:0.42 max:80 sd:14.5163
# 	3: "Fare" NUMERICAL mean:32.2042 min:0 max:512.329 sd:49.6655
# 	5: "Parch" NUMERICAL mean:0.381594 min:0 max:6 sd:0.805605
# 	6: "Pclass" NUMERICAL mean:2.30864 min:1 max:3 sd:0.835602
# 	8: "SibSp" NUMERICAL mean:0.523008 min:0 max:8 sd:1.10212
#
# CATEGORICAL_SET: 1 (8.33333%)
# 	4: "Name" CATEGORICAL_SET has-dict vocab-size:86 num-oods:1932 (216.835%) most-frequent:"<OOD>" 1932 (216.835%)
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1743111904.641794 18509509 kernel.cc:818] Configure learner
# W0000 00:00:1743111904.641906 18509509 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111904.641909 18509509 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111904.641910 18509509 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1743111904.641973 18509509 kernel.cc:831] Training config:
# learner: "GRADIENT_BOOSTED_TREES"
# features: "^Age$"
# features: "^Cabin$"
# features: "^Embarked$"
# features: "^Fare$"
# features: "^Name$"
# features: "^Parch$"
# features: "^Pclass$"
# features: "^Sex$"
# features: "^SibSp$"
# features: "^Ticket_item$"
# features: "^Ticket_number$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# random_seed: 0
# metadata {
#   framework: "TF Keras"
# }
# pure_serving_model: false
# [yggdrasil_decision_forests.model.gradient_boosted_trees.proto.gradient_boosted_trees_config] {
#   num_trees: 300
#   decision_tree {
#     max_depth: 6
#     min_examples: 5
#     in_split_min_examples_check: true
#     keep_non_leaf_label_distribution: true
#     num_candidate_attributes: -1
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#     uplift {
#       min_examples_in_treatment: 5
#       split_score: KULLBACK_LEIBLER
#     }
#     honest {
#       ratio_leaf_examples: 0.5
#       fixed_separation: false
#     }
#     numerical_vector_sequence {
#       max_num_test_examples: 1000
#       num_random_selected_anchors: 100
#     }
#   }
#   shrinkage: 0.1
#   loss: DEFAULT
#   validation_set_ratio: 0.1
#   validation_interval_in_trees: 1
#   early_stopping: VALIDATION_LOSS_INCREASE
#   early_stopping_num_trees_look_ahead: 30
#   l2_regularization: 0
#   lambda_loss: 1
#   mart {
#   }
#   adapt_subsample_for_maximum_training_duration: false
#   l1_regularization: 0
#   use_hessian_gain: false
#   l2_regularization_categorical: 1
#   xe_ndcg {
#     ndcg_truncation: 5
#   }
#   stochastic_gradient_boosting {
#     ratio: 1
#   }
#   apply_link_function: true
#   compute_permutation_variable_importance: false
#   early_stopping_initial_iteration: 10
# }
#
# I0000 00:00:1743111904.642012 18509509 kernel.cc:834] Deployment config:
# cache_path: "/var/folders/hc/xs3_7cjx0vg7ssqh_cxmkll00000gn/T/tmp2vldlzqi/working_cache"
# num_threads: 11
# try_resume_training: true
#
# I0000 00:00:1743111904.642089 18761996 kernel.cc:895] Train model
# I0000 00:00:1743111904.642381 18761996 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1743111904.642399 18761996 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 11 feature(s).
# I0000 00:00:1743111904.643129 18761996 gradient_boosted_trees.cc:1230] 797 examples used for training and 94 examples used for validation
# I0000 00:00:1743111904.643501 18761996 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1743111904.646265 18761996 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.241931 train-accuracy:0.613551 valid-loss:1.240037 valid-accuracy:0.638298 [total:0.00s iter:0.00s]
# I0000 00:00:1743111904.648868 18761996 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.170220 train-accuracy:0.723965 valid-loss:1.170693 valid-accuracy:0.734043 [total:0.01s iter:0.00s]
# I0000 00:00:1743111904.650566 18761996 gradient_boosted_trees.cc:1634] Train tree 3/300 train-loss:1.110877 train-accuracy:0.781681 valid-loss:1.112086 valid-accuracy:0.765957 [total:0.01s iter:0.00s]
# I0000 00:00:1743111904.710935 18761996 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.86709
# I0000 00:00:1743111904.710952 18761996 gradient_boosted_trees.cc:1669] Create final snapshot of the model at iteration 57
# I0000 00:00:1743111904.714088 18761996 gradient_boosted_trees.cc:279] Truncates the model to 28 tree(s) i.e. 28  iteration(s).
# I0000 00:00:1743111904.714437 18761996 gradient_boosted_trees.cc:341] Final model num-trees:28 valid-loss:0.867090 valid-accuracy:0.851064
# I0000 00:00:1743111904.714846 18761996 kernel.cc:926] Export model in log directory: /var/folders/hc/xs3_7cjx0vg7ssqh_cxmkll00000gn/T/tmp2vldlzqi with prefix 933fc89adf324bfb
# I0000 00:00:1743111904.715881 18761996 kernel.cc:944] Save model in resources
# I0000 00:00:1743111904.716540 18509509 abstract_model.cc:921] Model self evaluation:
# Task: CLASSIFICATION
# Label: __LABEL
# Loss (BINOMIAL_LOG_LIKELIHOOD): 0.86709
#
# Accuracy: 0.851064  CI95[W][0 1]
# ErrorRate: : 0.148936
#
#
# Confusion Table:
# truth\prediction
#     1   2
# 1  54   6
# 2   8  26
# Total: 94
#
#
# 2025-03-27 17:45:04.721779: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1206] Loading model from path /var/folders/hc/xs3_7cjx0vg7ssqh_cxmkll00000gn/T/tmp2vldlzqi/model/ with prefix 933fc89adf324bfb
# I0000 00:00:1743111904.723382 18509509 abstract_model.cc:1439] Engine "GradientBoostedTreesQuickScorerExtended" built
# 2025-03-27 17:45:04.723395: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1035] Use fast generic engine
# W0000 00:00:1743111904.865777 18509509 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111904.865789 18509509 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111904.865791 18509509 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1743111904.995761 18509509 kernel.cc:782] Start Yggdrasil model training
# I0000 00:00:1743111904.995771 18509509 kernel.cc:783] Collect training examples
# I0000 00:00:1743111904.995774 18509509 kernel.cc:795] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# column_guides {
#   column_name_pattern: "^Pclass$"
# }
# column_guides {
#   column_name_pattern: "^Name$"
# }
# column_guides {
#   column_name_pattern: "^Sex$"
# }
# column_guides {
#   column_name_pattern: "^Age$"
# }
# column_guides {
#   column_name_pattern: "^SibSp$"
# }
# column_guides {
#   column_name_pattern: "^Parch$"
# }
# column_guides {
#   column_name_pattern: "^Fare$"
# }
# column_guides {
#   column_name_pattern: "^Cabin$"
# }
# column_guides {
#   column_name_pattern: "^Embarked$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_number$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_item$"
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: true
# detect_numerical_as_discretized_numerical: false
#
# I0000 00:00:1743111904.995921 18509509 kernel.cc:401] Number of batches: 1
# I0000 00:00:1743111904.995924 18509509 kernel.cc:402] Number of examples: 891
# I0000 00:00:1743111904.996254 18509509 data_spec_inference.cc:354] 147 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Cabin (0 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111904.996428 18509509 data_spec_inference.cc:354] 1441 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Name (85 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111904.996574 18509509 data_spec_inference.cc:354] 28 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_item (16 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111904.996720 18509509 data_spec_inference.cc:354] 671 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_number (8 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111904.996999 18509509 kernel.cc:802] Training dataset:
# Number of records: 891
# Number of columns: 12
#
# Number of columns by type:
# 	CATEGORICAL: 6 (50%)
# 	NUMERICAL: 5 (41.6667%)
# 	CATEGORICAL_SET: 1 (8.33333%)
#
# Columns:
#
# CATEGORICAL: 6 (50%)
# 	1: "Cabin" CATEGORICAL num-nas:687 (77.1044%) has-dict vocab-size:1 num-oods:204 (100%)
# 	2: "Embarked" CATEGORICAL num-nas:2 (0.224467%) has-dict vocab-size:4 zero-ood-items most-frequent:"S" 644 (72.4409%)
# 	7: "Sex" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"male" 577 (64.7587%)
# 	9: "Ticket_item" CATEGORICAL has-dict vocab-size:17 num-oods:46 (5.16274%) most-frequent:"NONE" 665 (74.6352%)
# 	10: "Ticket_number" CATEGORICAL has-dict vocab-size:9 num-oods:842 (94.5006%) most-frequent:"<OOD>" 842 (94.5006%)
# 	11: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 5 (41.6667%)
# 	0: "Age" NUMERICAL num-nas:177 (19.8653%) mean:29.6991 min:0.42 max:80 sd:14.5163
# 	3: "Fare" NUMERICAL mean:32.2042 min:0 max:512.329 sd:49.6655
# 	5: "Parch" NUMERICAL mean:0.381594 min:0 max:6 sd:0.805605
# 	6: "Pclass" NUMERICAL mean:2.30864 min:1 max:3 sd:0.835602
# 	8: "SibSp" NUMERICAL mean:0.523008 min:0 max:8 sd:1.10212
#
# CATEGORICAL_SET: 1 (8.33333%)
# 	4: "Name" CATEGORICAL_SET has-dict vocab-size:86 num-oods:1932 (216.835%) most-frequent:"<OOD>" 1932 (216.835%)
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1743111904.997017 18509509 kernel.cc:818] Configure learner
# W0000 00:00:1743111904.997141 18509509 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111904.997143 18509509 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111904.997145 18509509 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1743111904.997210 18509509 kernel.cc:831] Training config:
# learner: "GRADIENT_BOOSTED_TREES"
# features: "^Age$"
# features: "^Cabin$"
# features: "^Embarked$"
# features: "^Fare$"
# features: "^Name$"
# features: "^Parch$"
# features: "^Pclass$"
# features: "^Sex$"
# features: "^SibSp$"
# features: "^Ticket_item$"
# features: "^Ticket_number$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# random_seed: 1
# metadata {
#   framework: "TF Keras"
# }
# pure_serving_model: false
# [yggdrasil_decision_forests.model.gradient_boosted_trees.proto.gradient_boosted_trees_config] {
#   num_trees: 300
#   decision_tree {
#     max_depth: 6
#     min_examples: 5
#     in_split_min_examples_check: true
#     keep_non_leaf_label_distribution: true
#     num_candidate_attributes: -1
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#     uplift {
#       min_examples_in_treatment: 5
#       split_score: KULLBACK_LEIBLER
#     }
#     honest {
#       ratio_leaf_examples: 0.5
#       fixed_separation: false
#     }
#     numerical_vector_sequence {
#       max_num_test_examples: 1000
#       num_random_selected_anchors: 100
#     }
#   }
#   shrinkage: 0.1
#   loss: DEFAULT
#   validation_set_ratio: 0.1
#   validation_interval_in_trees: 1
#   early_stopping: VALIDATION_LOSS_INCREASE
#   early_stopping_num_trees_look_ahead: 30
#   l2_regularization: 0
#   lambda_loss: 1
#   mart {
#   }
#   adapt_subsample_for_maximum_training_duration: false
#   l1_regularization: 0
#   use_hessian_gain: false
#   l2_regularization_categorical: 1
#   xe_ndcg {
#     ndcg_truncation: 5
#   }
#   stochastic_gradient_boosting {
#     ratio: 1
#   }
#   apply_link_function: true
#   compute_permutation_variable_importance: false
#   early_stopping_initial_iteration: 10
# }
#
# I0000 00:00:1743111904.997234 18509509 kernel.cc:834] Deployment config:
# cache_path: "/var/folders/hc/xs3_7cjx0vg7ssqh_cxmkll00000gn/T/tmp2erq5nf3/working_cache"
# num_threads: 11
# try_resume_training: true
#
# I0000 00:00:1743111904.997270 18762717 kernel.cc:895] Train model
# I0000 00:00:1743111904.997313 18762717 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1743111904.997318 18762717 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 11 feature(s).
# I0000 00:00:1743111904.997556 18762717 gradient_boosted_trees.cc:1230] 783 examples used for training and 108 examples used for validation
# I0000 00:00:1743111904.997876 18762717 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1743111905.000000 18762717 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.254551 train-accuracy:0.610473 valid-loss:1.197710 valid-accuracy:0.657407 [total:0.00s iter:0.00s]
# I0000 00:00:1743111905.002263 18762717 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.183225 train-accuracy:0.670498 valid-loss:1.125180 valid-accuracy:0.722222 [total:0.00s iter:0.00s]
# I0000 00:00:1743111905.134744 18762717 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.729064
# I0000 00:00:1743111905.134756 18762717 gradient_boosted_trees.cc:1669] Create final snapshot of the model at iteration 110
# I0000 00:00:1743111905.138358 18762717 gradient_boosted_trees.cc:279] Truncates the model to 81 tree(s) i.e. 81  iteration(s).
# I0000 00:00:1743111905.138662 18762717 gradient_boosted_trees.cc:341] Final model num-trees:81 valid-loss:0.729064 valid-accuracy:0.842593
# I0000 00:00:1743111905.139483 18762717 kernel.cc:926] Export model in log directory: /var/folders/hc/xs3_7cjx0vg7ssqh_cxmkll00000gn/T/tmp2erq5nf3 with prefix 216ceac17e534f6c
# I0000 00:00:1743111905.141514 18762717 kernel.cc:944] Save model in resources
# I0000 00:00:1743111905.142266 18509509 abstract_model.cc:921] Model self evaluation:
# Task: CLASSIFICATION
# Label: __LABEL
# Loss (BINOMIAL_LOG_LIKELIHOOD): 0.729064
#
# Accuracy: 0.842593  CI95[W][0 1]
# ErrorRate: : 0.157407
#
#
# Confusion Table:
# truth\prediction
#     1   2
# 1  61  10
# 2   7  30
# Total: 108
#
#
# 2025-03-27 17:45:05.148015: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1206] Loading model from path /var/folders/hc/xs3_7cjx0vg7ssqh_cxmkll00000gn/T/tmp2erq5nf3/model/ with prefix 216ceac17e534f6c
# 2025-03-27 17:45:05.151765: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1035] Use fast generic engine
# W0000 00:00:1743111905.284678 18509509 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111905.284687 18509509 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111905.284689 18509509 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1743111905.387112 18509509 kernel.cc:782] Start Yggdrasil model training
# I0000 00:00:1743111905.387121 18509509 kernel.cc:783] Collect training examples
# I0000 00:00:1743111905.387125 18509509 kernel.cc:795] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# column_guides {
#   column_name_pattern: "^Pclass$"
# }
# column_guides {
#   column_name_pattern: "^Name$"
# }
# column_guides {
#   column_name_pattern: "^Sex$"
# }
# column_guides {
#   column_name_pattern: "^Age$"
# }
# column_guides {
#   column_name_pattern: "^SibSp$"
# }
# column_guides {
#   column_name_pattern: "^Parch$"
# }
# column_guides {
#   column_name_pattern: "^Fare$"
# }
# column_guides {
#   column_name_pattern: "^Cabin$"
# }
# column_guides {
#   column_name_pattern: "^Embarked$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_number$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_item$"
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: true
# detect_numerical_as_discretized_numerical: false
#
# I0000 00:00:1743111905.387256 18509509 kernel.cc:401] Number of batches: 1
# I0000 00:00:1743111905.387259 18509509 kernel.cc:402] Number of examples: 891
# I0000 00:00:1743111905.387553 18509509 data_spec_inference.cc:354] 147 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Cabin (0 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111905.387719 18509509 data_spec_inference.cc:354] 1441 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Name (85 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111905.387817 18509509 data_spec_inference.cc:354] 28 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_item (16 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111905.387898 18509509 data_spec_inference.cc:354] 671 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_number (8 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111905.388138 18509509 kernel.cc:802] Training dataset:
# Number of records: 891
# Number of columns: 12
#
# Number of columns by type:
# 	CATEGORICAL: 6 (50%)
# 	NUMERICAL: 5 (41.6667%)
# 	CATEGORICAL_SET: 1 (8.33333%)
#
# Columns:
#
# CATEGORICAL: 6 (50%)
# 	1: "Cabin" CATEGORICAL num-nas:687 (77.1044%) has-dict vocab-size:1 num-oods:204 (100%)
# 	2: "Embarked" CATEGORICAL num-nas:2 (0.224467%) has-dict vocab-size:4 zero-ood-items most-frequent:"S" 644 (72.4409%)
# 	7: "Sex" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"male" 577 (64.7587%)
# 	9: "Ticket_item" CATEGORICAL has-dict vocab-size:17 num-oods:46 (5.16274%) most-frequent:"NONE" 665 (74.6352%)
# 	10: "Ticket_number" CATEGORICAL has-dict vocab-size:9 num-oods:842 (94.5006%) most-frequent:"<OOD>" 842 (94.5006%)
# 	11: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 5 (41.6667%)
# 	0: "Age" NUMERICAL num-nas:177 (19.8653%) mean:29.6991 min:0.42 max:80 sd:14.5163
# 	3: "Fare" NUMERICAL mean:32.2042 min:0 max:512.329 sd:49.6655
# 	5: "Parch" NUMERICAL mean:0.381594 min:0 max:6 sd:0.805605
# 	6: "Pclass" NUMERICAL mean:2.30864 min:1 max:3 sd:0.835602
# 	8: "SibSp" NUMERICAL mean:0.523008 min:0 max:8 sd:1.10212
#
# CATEGORICAL_SET: 1 (8.33333%)
# 	4: "Name" CATEGORICAL_SET has-dict vocab-size:86 num-oods:1932 (216.835%) most-frequent:"<OOD>" 1932 (216.835%)
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1743111905.388150 18509509 kernel.cc:818] Configure learner
# W0000 00:00:1743111905.388264 18509509 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111905.388266 18509509 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111905.388267 18509509 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1743111905.388325 18509509 kernel.cc:831] Training config:
# learner: "GRADIENT_BOOSTED_TREES"
# features: "^Age$"
# features: "^Cabin$"
# features: "^Embarked$"
# features: "^Fare$"
# features: "^Name$"
# features: "^Parch$"
# features: "^Pclass$"
# features: "^Sex$"
# features: "^SibSp$"
# features: "^Ticket_item$"
# features: "^Ticket_number$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# random_seed: 2
# metadata {
#   framework: "TF Keras"
# }
# pure_serving_model: false
# [yggdrasil_decision_forests.model.gradient_boosted_trees.proto.gradient_boosted_trees_config] {
#   num_trees: 300
#   decision_tree {
#     max_depth: 6
#     min_examples: 5
#     in_split_min_examples_check: true
#     keep_non_leaf_label_distribution: true
#     num_candidate_attributes: -1
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#     uplift {
#       min_examples_in_treatment: 5
#       split_score: KULLBACK_LEIBLER
#     }
#     honest {
#       ratio_leaf_examples: 0.5
#       fixed_separation: false
#     }
#     numerical_vector_sequence {
#       max_num_test_examples: 1000
#       num_random_selected_anchors: 100
#     }
#   }
#   shrinkage: 0.1
#   loss: DEFAULT
#   validation_set_ratio: 0.1
#   validation_interval_in_trees: 1
#   early_stopping: VALIDATION_LOSS_INCREASE
#   early_stopping_num_trees_look_ahead: 30
#   l2_regularization: 0
#   lambda_loss: 1
#   mart {
#   }
#   adapt_subsample_for_maximum_training_duration: false
#   l1_regularization: 0
#   use_hessian_gain: false
#   l2_regularization_categorical: 1
#   xe_ndcg {
#     ndcg_truncation: 5
#   }
#   stochastic_gradient_boosting {
#     ratio: 1
#   }
#   apply_link_function: true
#   compute_permutation_variable_importance: false
#   early_stopping_initial_iteration: 10
# }
#
# I0000 00:00:1743111905.388351 18509509 kernel.cc:834] Deployment config:
# cache_path: "/var/folders/hc/xs3_7cjx0vg7ssqh_cxmkll00000gn/T/tmpff1n9n39/working_cache"
# num_threads: 11
# try_resume_training: true
#
# I0000 00:00:1743111905.388383 18764021 kernel.cc:895] Train model
# I0000 00:00:1743111905.388438 18764021 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1743111905.388443 18764021 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 11 feature(s).
# I0000 00:00:1743111905.388739 18764021 gradient_boosted_trees.cc:1230] 804 examples used for training and 87 examples used for validation
# I0000 00:00:1743111905.389043 18764021 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1743111905.391414 18764021 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.222344 train-accuracy:0.628109 valid-loss:1.342338 valid-accuracy:0.505747 [total:0.00s iter:0.00s]
# I0000 00:00:1743111905.393485 18764021 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.157649 train-accuracy:0.628109 valid-loss:1.277133 valid-accuracy:0.505747 [total:0.00s iter:0.00s]
# I0000 00:00:1743111905.515341 18764021 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.759081
# I0000 00:00:1743111905.515354 18764021 gradient_boosted_trees.cc:1669] Create final snapshot of the model at iteration 114
# I0000 00:00:1743111905.518638 18764021 gradient_boosted_trees.cc:279] Truncates the model to 85 tree(s) i.e. 85  iteration(s).
# I0000 00:00:1743111905.518940 18764021 gradient_boosted_trees.cc:341] Final model num-trees:85 valid-loss:0.759081 valid-accuracy:0.827586
# I0000 00:00:1743111905.519833 18764021 kernel.cc:926] Export model in log directory: /var/folders/hc/xs3_7cjx0vg7ssqh_cxmkll00000gn/T/tmpff1n9n39 with prefix 27db172450994af4
# I0000 00:00:1743111905.521366 18764021 kernel.cc:944] Save model in resources
# I0000 00:00:1743111905.522014 18509509 abstract_model.cc:921] Model self evaluation:
# Task: CLASSIFICATION
# Label: __LABEL
# Loss (BINOMIAL_LOG_LIKELIHOOD): 0.759081
#
# Accuracy: 0.827586  CI95[W][0 1]
# ErrorRate: : 0.172414
#
#
# Confusion Table:
# truth\prediction
#     1   2
# 1  42   2
# 2  13  30
# Total: 87
#
#
# 2025-03-27 17:45:05.527914: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1206] Loading model from path /var/folders/hc/xs3_7cjx0vg7ssqh_cxmkll00000gn/T/tmpff1n9n39/model/ with prefix 27db172450994af4
# 2025-03-27 17:45:05.531305: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1035] Use fast generic engine
# W0000 00:00:1743111905.672552 18509509 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111905.672562 18509509 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111905.672564 18509509 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1743111905.792368 18509509 kernel.cc:782] Start Yggdrasil model training
# I0000 00:00:1743111905.792379 18509509 kernel.cc:783] Collect training examples
# I0000 00:00:1743111905.792383 18509509 kernel.cc:795] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# column_guides {
#   column_name_pattern: "^Pclass$"
# }
# column_guides {
#   column_name_pattern: "^Name$"
# }
# column_guides {
#   column_name_pattern: "^Sex$"
# }
# column_guides {
#   column_name_pattern: "^Age$"
# }
# column_guides {
#   column_name_pattern: "^SibSp$"
# }
# column_guides {
#   column_name_pattern: "^Parch$"
# }
# column_guides {
#   column_name_pattern: "^Fare$"
# }
# column_guides {
#   column_name_pattern: "^Cabin$"
# }
# column_guides {
#   column_name_pattern: "^Embarked$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_number$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_item$"
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: true
# detect_numerical_as_discretized_numerical: false
#
# I0000 00:00:1743111905.792599 18509509 kernel.cc:401] Number of batches: 1
# I0000 00:00:1743111905.792605 18509509 kernel.cc:402] Number of examples: 891
# I0000 00:00:1743111905.792942 18509509 data_spec_inference.cc:354] 147 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Cabin (0 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111905.793132 18509509 data_spec_inference.cc:354] 1441 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Name (85 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111905.793256 18509509 data_spec_inference.cc:354] 28 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_item (16 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111905.793340 18509509 data_spec_inference.cc:354] 671 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_number (8 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111905.793613 18509509 kernel.cc:802] Training dataset:
# Number of records: 891
# Number of columns: 12
#
# Number of columns by type:
# 	CATEGORICAL: 6 (50%)
# 	NUMERICAL: 5 (41.6667%)
# 	CATEGORICAL_SET: 1 (8.33333%)
#
# Columns:
#
# CATEGORICAL: 6 (50%)
# 	1: "Cabin" CATEGORICAL num-nas:687 (77.1044%) has-dict vocab-size:1 num-oods:204 (100%)
# 	2: "Embarked" CATEGORICAL num-nas:2 (0.224467%) has-dict vocab-size:4 zero-ood-items most-frequent:"S" 644 (72.4409%)
# 	7: "Sex" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"male" 577 (64.7587%)
# 	9: "Ticket_item" CATEGORICAL has-dict vocab-size:17 num-oods:46 (5.16274%) most-frequent:"NONE" 665 (74.6352%)
# 	10: "Ticket_number" CATEGORICAL has-dict vocab-size:9 num-oods:842 (94.5006%) most-frequent:"<OOD>" 842 (94.5006%)
# 	11: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 5 (41.6667%)
# 	0: "Age" NUMERICAL num-nas:177 (19.8653%) mean:29.6991 min:0.42 max:80 sd:14.5163
# 	3: "Fare" NUMERICAL mean:32.2042 min:0 max:512.329 sd:49.6655
# 	5: "Parch" NUMERICAL mean:0.381594 min:0 max:6 sd:0.805605
# 	6: "Pclass" NUMERICAL mean:2.30864 min:1 max:3 sd:0.835602
# 	8: "SibSp" NUMERICAL mean:0.523008 min:0 max:8 sd:1.10212
#
# CATEGORICAL_SET: 1 (8.33333%)
# 	4: "Name" CATEGORICAL_SET has-dict vocab-size:86 num-oods:1932 (216.835%) most-frequent:"<OOD>" 1932 (216.835%)
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1743111905.793629 18509509 kernel.cc:818] Configure learner
# W0000 00:00:1743111905.793748 18509509 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111905.793750 18509509 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111905.793751 18509509 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1743111905.793809 18509509 kernel.cc:831] Training config:
# learner: "GRADIENT_BOOSTED_TREES"
# features: "^Age$"
# features: "^Cabin$"
# features: "^Embarked$"
# features: "^Fare$"
# features: "^Name$"
# features: "^Parch$"
# features: "^Pclass$"
# features: "^Sex$"
# features: "^SibSp$"
# features: "^Ticket_item$"
# features: "^Ticket_number$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# random_seed: 3
# metadata {
#   framework: "TF Keras"
# }
# pure_serving_model: false
# [yggdrasil_decision_forests.model.gradient_boosted_trees.proto.gradient_boosted_trees_config] {
#   num_trees: 300
#   decision_tree {
#     max_depth: 6
#     min_examples: 5
#     in_split_min_examples_check: true
#     keep_non_leaf_label_distribution: true
#     num_candidate_attributes: -1
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#     uplift {
#       min_examples_in_treatment: 5
#       split_score: KULLBACK_LEIBLER
#     }
#     honest {
#       ratio_leaf_examples: 0.5
#       fixed_separation: false
#     }
#     numerical_vector_sequence {
#       max_num_test_examples: 1000
#       num_random_selected_anchors: 100
#     }
#   }
#   shrinkage: 0.1
#   loss: DEFAULT
#   validation_set_ratio: 0.1
#   validation_interval_in_trees: 1
#   early_stopping: VALIDATION_LOSS_INCREASE
#   early_stopping_num_trees_look_ahead: 30
#   l2_regularization: 0
#   lambda_loss: 1
#   mart {
#   }
#   adapt_subsample_for_maximum_training_duration: false
#   l1_regularization: 0
#   use_hessian_gain: false
#   l2_regularization_categorical: 1
#   xe_ndcg {
#     ndcg_truncation: 5
#   }
#   stochastic_gradient_boosting {
#     ratio: 1
#   }
#   apply_link_function: true
#   compute_permutation_variable_importance: false
#   early_stopping_initial_iteration: 10
# }
#
# I0000 00:00:1743111905.793838 18509509 kernel.cc:834] Deployment config:
# cache_path: "/var/folders/hc/xs3_7cjx0vg7ssqh_cxmkll00000gn/T/tmpt9nkf4zt/working_cache"
# num_threads: 11
# try_resume_training: true
#
# I0000 00:00:1743111905.793892 18765370 kernel.cc:895] Train model
# I0000 00:00:1743111905.793936 18765370 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1743111905.793940 18765370 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 11 feature(s).
# I0000 00:00:1743111905.794132 18765370 gradient_boosted_trees.cc:1230] 795 examples used for training and 96 examples used for validation
# I0000 00:00:1743111905.794461 18765370 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1743111905.796921 18765370 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.222005 train-accuracy:0.623899 valid-loss:1.298973 valid-accuracy:0.552083 [total:0.00s iter:0.00s]
# I0000 00:00:1743111905.798936 18765370 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.150968 train-accuracy:0.623899 valid-loss:1.226666 valid-accuracy:0.552083 [total:0.00s iter:0.00s]
# I0000 00:00:1743111905.888784 18765370 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.784526
# I0000 00:00:1743111905.888797 18765370 gradient_boosted_trees.cc:1669] Create final snapshot of the model at iteration 89
# I0000 00:00:1743111905.891777 18765370 gradient_boosted_trees.cc:279] Truncates the model to 60 tree(s) i.e. 60  iteration(s).
# I0000 00:00:1743111905.892035 18765370 gradient_boosted_trees.cc:341] Final model num-trees:60 valid-loss:0.784526 valid-accuracy:0.833333
# I0000 00:00:1743111905.892935 18765370 kernel.cc:926] Export model in log directory: /var/folders/hc/xs3_7cjx0vg7ssqh_cxmkll00000gn/T/tmpt9nkf4zt with prefix e526e7fdf9554b2d
# I0000 00:00:1743111905.894058 18765370 kernel.cc:944] Save model in resources
# I0000 00:00:1743111905.894730 18509509 abstract_model.cc:921] Model self evaluation:
# Task: CLASSIFICATION
# Label: __LABEL
# Loss (BINOMIAL_LOG_LIKELIHOOD): 0.784526
#
# Accuracy: 0.833333  CI95[W][0 1]
# ErrorRate: : 0.166667
#
#
# Confusion Table:
# truth\prediction
#     1   2
# 1  52   1
# 2  15  28
# Total: 96
#
#
# 2025-03-27 17:45:05.899402: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1206] Loading model from path /var/folders/hc/xs3_7cjx0vg7ssqh_cxmkll00000gn/T/tmpt9nkf4zt/model/ with prefix e526e7fdf9554b2d
# 2025-03-27 17:45:05.902302: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1035] Use fast generic engine
# W0000 00:00:1743111906.037152 18509509 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111906.037162 18509509 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111906.037163 18509509 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1743111906.145959 18509509 kernel.cc:782] Start Yggdrasil model training
# I0000 00:00:1743111906.145969 18509509 kernel.cc:783] Collect training examples
# I0000 00:00:1743111906.145972 18509509 kernel.cc:795] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# column_guides {
#   column_name_pattern: "^Pclass$"
# }
# column_guides {
#   column_name_pattern: "^Name$"
# }
# column_guides {
#   column_name_pattern: "^Sex$"
# }
# column_guides {
#   column_name_pattern: "^Age$"
# }
# column_guides {
#   column_name_pattern: "^SibSp$"
# }
# column_guides {
#   column_name_pattern: "^Parch$"
# }
# column_guides {
#   column_name_pattern: "^Fare$"
# }
# column_guides {
#   column_name_pattern: "^Cabin$"
# }
# column_guides {
#   column_name_pattern: "^Embarked$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_number$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_item$"
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: true
# detect_numerical_as_discretized_numerical: false
#
# I0000 00:00:1743111906.146100 18509509 kernel.cc:401] Number of batches: 1
# I0000 00:00:1743111906.146104 18509509 kernel.cc:402] Number of examples: 891
# I0000 00:00:1743111906.146403 18509509 data_spec_inference.cc:354] 147 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Cabin (0 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111906.146572 18509509 data_spec_inference.cc:354] 1441 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Name (85 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111906.146670 18509509 data_spec_inference.cc:354] 28 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_item (16 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111906.146753 18509509 data_spec_inference.cc:354] 671 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_number (8 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111906.147002 18509509 kernel.cc:802] Training dataset:
# Number of records: 891
# Number of columns: 12
#
# Number of columns by type:
# 	CATEGORICAL: 6 (50%)
# 	NUMERICAL: 5 (41.6667%)
# 	CATEGORICAL_SET: 1 (8.33333%)
#
# Columns:
#
# CATEGORICAL: 6 (50%)
# 	1: "Cabin" CATEGORICAL num-nas:687 (77.1044%) has-dict vocab-size:1 num-oods:204 (100%)
# 	2: "Embarked" CATEGORICAL num-nas:2 (0.224467%) has-dict vocab-size:4 zero-ood-items most-frequent:"S" 644 (72.4409%)
# 	7: "Sex" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"male" 577 (64.7587%)
# 	9: "Ticket_item" CATEGORICAL has-dict vocab-size:17 num-oods:46 (5.16274%) most-frequent:"NONE" 665 (74.6352%)
# 	10: "Ticket_number" CATEGORICAL has-dict vocab-size:9 num-oods:842 (94.5006%) most-frequent:"<OOD>" 842 (94.5006%)
# 	11: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 5 (41.6667%)
# 	0: "Age" NUMERICAL num-nas:177 (19.8653%) mean:29.6991 min:0.42 max:80 sd:14.5163
# 	3: "Fare" NUMERICAL mean:32.2042 min:0 max:512.329 sd:49.6655
# 	5: "Parch" NUMERICAL mean:0.381594 min:0 max:6 sd:0.805605
# 	6: "Pclass" NUMERICAL mean:2.30864 min:1 max:3 sd:0.835602
# 	8: "SibSp" NUMERICAL mean:0.523008 min:0 max:8 sd:1.10212
#
# CATEGORICAL_SET: 1 (8.33333%)
# 	4: "Name" CATEGORICAL_SET has-dict vocab-size:86 num-oods:1932 (216.835%) most-frequent:"<OOD>" 1932 (216.835%)
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1743111906.147014 18509509 kernel.cc:818] Configure learner
# W0000 00:00:1743111906.147138 18509509 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111906.147139 18509509 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111906.147141 18509509 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1743111906.147198 18509509 kernel.cc:831] Training config:
# learner: "GRADIENT_BOOSTED_TREES"
# features: "^Age$"
# features: "^Cabin$"
# features: "^Embarked$"
# features: "^Fare$"
# features: "^Name$"
# features: "^Parch$"
# features: "^Pclass$"
# features: "^Sex$"
# features: "^SibSp$"
# features: "^Ticket_item$"
# features: "^Ticket_number$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# random_seed: 4
# metadata {
#   framework: "TF Keras"
# }
# pure_serving_model: false
# [yggdrasil_decision_forests.model.gradient_boosted_trees.proto.gradient_boosted_trees_config] {
#   num_trees: 300
#   decision_tree {
#     max_depth: 6
#     min_examples: 5
#     in_split_min_examples_check: true
#     keep_non_leaf_label_distribution: true
#     num_candidate_attributes: -1
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#     uplift {
#       min_examples_in_treatment: 5
#       split_score: KULLBACK_LEIBLER
#     }
#     honest {
#       ratio_leaf_examples: 0.5
#       fixed_separation: false
#     }
#     numerical_vector_sequence {
#       max_num_test_examples: 1000
#       num_random_selected_anchors: 100
#     }
#   }
#   shrinkage: 0.1
#   loss: DEFAULT
#   validation_set_ratio: 0.1
#   validation_interval_in_trees: 1
#   early_stopping: VALIDATION_LOSS_INCREASE
#   early_stopping_num_trees_look_ahead: 30
#   l2_regularization: 0
#   lambda_loss: 1
#   mart {
#   }
#   adapt_subsample_for_maximum_training_duration: false
#   l1_regularization: 0
#   use_hessian_gain: false
#   l2_regularization_categorical: 1
#   xe_ndcg {
#     ndcg_truncation: 5
#   }
#   stochastic_gradient_boosting {
#     ratio: 1
#   }
#   apply_link_function: true
#   compute_permutation_variable_importance: false
#   early_stopping_initial_iteration: 10
# }
#
# I0000 00:00:1743111906.147225 18509509 kernel.cc:834] Deployment config:
# cache_path: "/var/folders/hc/xs3_7cjx0vg7ssqh_cxmkll00000gn/T/tmpt4ldr5r7/working_cache"
# num_threads: 11
# try_resume_training: true
#
# I0000 00:00:1743111906.147265 18766444 kernel.cc:895] Train model
# I0000 00:00:1743111906.147308 18766444 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1743111906.147313 18766444 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 11 feature(s).
# I0000 00:00:1743111906.147527 18766444 gradient_boosted_trees.cc:1230] 798 examples used for training and 93 examples used for validation
# I0000 00:00:1743111906.147811 18766444 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1743111906.149924 18766444 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.250428 train-accuracy:0.607769 valid-loss:1.199280 valid-accuracy:0.688172 [total:0.00s iter:0.00s]
# I0000 00:00:1743111906.152406 18766444 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.167173 train-accuracy:0.770677 valid-loss:1.142233 valid-accuracy:0.774194 [total:0.00s iter:0.00s]
# I0000 00:00:1743111906.215031 18766444 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.906904
# I0000 00:00:1743111906.215043 18766444 gradient_boosted_trees.cc:1669] Create final snapshot of the model at iteration 55
# I0000 00:00:1743111906.216307 18766444 gradient_boosted_trees.cc:279] Truncates the model to 26 tree(s) i.e. 26  iteration(s).
# I0000 00:00:1743111906.216539 18766444 gradient_boosted_trees.cc:341] Final model num-trees:26 valid-loss:0.906904 valid-accuracy:0.817204
# I0000 00:00:1743111906.216879 18766444 kernel.cc:926] Export model in log directory: /var/folders/hc/xs3_7cjx0vg7ssqh_cxmkll00000gn/T/tmpt4ldr5r7 with prefix e976c10eed244226
# I0000 00:00:1743111906.217840 18766444 kernel.cc:944] Save model in resources
# I0000 00:00:1743111906.218446 18509509 abstract_model.cc:921] Model self evaluation:
# Task: CLASSIFICATION
# Label: __LABEL
# Loss (BINOMIAL_LOG_LIKELIHOOD): 0.906904
#
# Accuracy: 0.817204  CI95[W][0 1]
# ErrorRate: : 0.182796
#
#
# Confusion Table:
# truth\prediction
#     1   2
# 1  55   9
# 2   8  21
# Total: 93
#
#
# 2025-03-27 17:45:06.222487: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1206] Loading model from path /var/folders/hc/xs3_7cjx0vg7ssqh_cxmkll00000gn/T/tmpt4ldr5r7/model/ with prefix e976c10eed244226
# ...
# 	7: "Sex" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"male" 577 (64.7587%)
# 	9: "Ticket_item" CATEGORICAL has-dict vocab-size:17 num-oods:46 (5.16274%) most-frequent:"NONE" 665 (74.6352%)
# 	10: "Ticket_number" CATEGORICAL has-dict vocab-size:9 num-oods:842 (94.5006%) most-frequent:"<OOD>" 842 (94.5006%)
# 	11: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 5 (41.6667%)
# 	0: "Age" NUMERICAL num-nas:177 (19.8653%) mean:29.6991 min:0.42 max:80 sd:14.5163
# 	3: "Fare" NUMERICAL mean:32.2042 min:0 max:512.329 sd:49.6655
# 	5: "Parch" NUMERICAL mean:0.381594 min:0 max:6 sd:0.805605
# 	6: "Pclass" NUMERICAL mean:2.30864 min:1 max:3 sd:0.835602
# 	8: "SibSp" NUMERICAL mean:0.523008 min:0 max:8 sd:1.10212
#
# CATEGORICAL_SET: 1 (8.33333%)
# 	4: "Name" CATEGORICAL_SET has-dict vocab-size:86 num-oods:1932 (216.835%) most-frequent:"<OOD>" 1932 (216.835%)
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1743111976.133005 18509509 kernel.cc:818] Configure learner
# W0000 00:00:1743111976.133120 18509509 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111976.133122 18509509 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111976.133123 18509509 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1743111976.133176 18509509 kernel.cc:831] Training config:
# learner: "GRADIENT_BOOSTED_TREES"
# features: "^Age$"
# features: "^Cabin$"
# features: "^Embarked$"
# features: "^Fare$"
# features: "^Name$"
# features: "^Parch$"
# features: "^Pclass$"
# features: "^Sex$"
# features: "^SibSp$"
# features: "^Ticket_item$"
# features: "^Ticket_number$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# random_seed: 198
# metadata {
#   framework: "TF Keras"
# }
# pure_serving_model: false
# [yggdrasil_decision_forests.model.gradient_boosted_trees.proto.gradient_boosted_trees_config] {
#   num_trees: 300
#   decision_tree {
#     max_depth: 6
#     min_examples: 5
#     in_split_min_examples_check: true
#     keep_non_leaf_label_distribution: true
#     num_candidate_attributes: -1
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#     uplift {
#       min_examples_in_treatment: 5
#       split_score: KULLBACK_LEIBLER
#     }
#     honest {
#       ratio_leaf_examples: 0.5
#       fixed_separation: false
#     }
#     numerical_vector_sequence {
#       max_num_test_examples: 1000
#       num_random_selected_anchors: 100
#     }
#   }
#   shrinkage: 0.1
#   loss: DEFAULT
#   validation_set_ratio: 0.1
#   validation_interval_in_trees: 1
#   early_stopping: VALIDATION_LOSS_INCREASE
#   early_stopping_num_trees_look_ahead: 30
#   l2_regularization: 0
#   lambda_loss: 1
#   mart {
#   }
#   adapt_subsample_for_maximum_training_duration: false
#   l1_regularization: 0
#   use_hessian_gain: false
#   l2_regularization_categorical: 1
#   xe_ndcg {
#     ndcg_truncation: 5
#   }
#   stochastic_gradient_boosting {
#     ratio: 1
#   }
#   apply_link_function: true
#   compute_permutation_variable_importance: false
#   early_stopping_initial_iteration: 10
# }
#
# I0000 00:00:1743111976.133200 18509509 kernel.cc:834] Deployment config:
# cache_path: "/var/folders/hc/xs3_7cjx0vg7ssqh_cxmkll00000gn/T/tmpsrlqct_u/working_cache"
# num_threads: 11
# try_resume_training: true
#
# I0000 00:00:1743111976.133233 18986170 kernel.cc:895] Train model
# I0000 00:00:1743111976.133268 18986170 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1743111976.133273 18986170 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 11 feature(s).
# I0000 00:00:1743111976.133463 18986170 gradient_boosted_trees.cc:1230] 785 examples used for training and 106 examples used for validation
# I0000 00:00:1743111976.133846 18986170 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1743111976.136802 18986170 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.237235 train-accuracy:0.622930 valid-loss:1.293979 valid-accuracy:0.566038 [total:0.00s iter:0.00s]
# I0000 00:00:1743111976.139230 18986170 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.155334 train-accuracy:0.629299 valid-loss:1.221947 valid-accuracy:0.556604 [total:0.01s iter:0.00s]
# I0000 00:00:1743111976.202685 18986170 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.918837
# I0000 00:00:1743111976.202692 18986170 gradient_boosted_trees.cc:1669] Create final snapshot of the model at iteration 54
# I0000 00:00:1743111976.203781 18986170 gradient_boosted_trees.cc:279] Truncates the model to 25 tree(s) i.e. 25  iteration(s).
# I0000 00:00:1743111976.204029 18986170 gradient_boosted_trees.cc:341] Final model num-trees:25 valid-loss:0.918837 valid-accuracy:0.783019
# I0000 00:00:1743111976.204319 18986170 kernel.cc:926] Export model in log directory: /var/folders/hc/xs3_7cjx0vg7ssqh_cxmkll00000gn/T/tmpsrlqct_u with prefix 26f633e653254008
# I0000 00:00:1743111976.205281 18986170 kernel.cc:944] Save model in resources
# I0000 00:00:1743111976.205752 18509509 abstract_model.cc:921] Model self evaluation:
# Task: CLASSIFICATION
# Label: __LABEL
# Loss (BINOMIAL_LOG_LIKELIHOOD): 0.918837
#
# Accuracy: 0.783019  CI95[W][0 1]
# ErrorRate: : 0.216981
#
#
# Confusion Table:
# truth\prediction
#     1   2
# 1  53   7
# 2  16  30
# Total: 106
#
#
# 2025-03-27 17:46:16.209804: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1206] Loading model from path /var/folders/hc/xs3_7cjx0vg7ssqh_cxmkll00000gn/T/tmpsrlqct_u/model/ with prefix 26f633e653254008
# 2025-03-27 17:46:16.210929: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1035] Use fast generic engine
# W0000 00:00:1743111976.325040 18509509 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111976.325048 18509509 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111976.325049 18509509 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1743111976.434943 18509509 kernel.cc:782] Start Yggdrasil model training
# I0000 00:00:1743111976.434954 18509509 kernel.cc:783] Collect training examples
# I0000 00:00:1743111976.434957 18509509 kernel.cc:795] Dataspec guide:
# column_guides {
#   column_name_pattern: "^__LABEL$"
#   type: CATEGORICAL
#   categorial {
#     min_vocab_frequency: 0
#     max_vocab_count: -1
#   }
# }
# column_guides {
#   column_name_pattern: "^Pclass$"
# }
# column_guides {
#   column_name_pattern: "^Name$"
# }
# column_guides {
#   column_name_pattern: "^Sex$"
# }
# column_guides {
#   column_name_pattern: "^Age$"
# }
# column_guides {
#   column_name_pattern: "^SibSp$"
# }
# column_guides {
#   column_name_pattern: "^Parch$"
# }
# column_guides {
#   column_name_pattern: "^Fare$"
# }
# column_guides {
#   column_name_pattern: "^Cabin$"
# }
# column_guides {
#   column_name_pattern: "^Embarked$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_number$"
# }
# column_guides {
#   column_name_pattern: "^Ticket_item$"
# }
# default_column_guide {
#   categorial {
#     max_vocab_count: 2000
#   }
#   discretized_numerical {
#     maximum_num_bins: 255
#   }
# }
# ignore_columns_without_guides: true
# detect_numerical_as_discretized_numerical: false
#
# I0000 00:00:1743111976.435074 18509509 kernel.cc:401] Number of batches: 1
# I0000 00:00:1743111976.435077 18509509 kernel.cc:402] Number of examples: 891
# I0000 00:00:1743111976.435391 18509509 data_spec_inference.cc:354] 147 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Cabin (0 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111976.435561 18509509 data_spec_inference.cc:354] 1441 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Name (85 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111976.435661 18509509 data_spec_inference.cc:354] 28 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_item (16 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111976.435737 18509509 data_spec_inference.cc:354] 671 item(s) have been pruned (i.e. they are considered out of dictionary) for the column Ticket_number (8 item(s) left) because min_value_count=5 and max_number_of_unique_values=2000
# I0000 00:00:1743111976.435981 18509509 kernel.cc:802] Training dataset:
# Number of records: 891
# Number of columns: 12
#
# Number of columns by type:
# 	CATEGORICAL: 6 (50%)
# 	NUMERICAL: 5 (41.6667%)
# 	CATEGORICAL_SET: 1 (8.33333%)
#
# Columns:
#
# CATEGORICAL: 6 (50%)
# 	1: "Cabin" CATEGORICAL num-nas:687 (77.1044%) has-dict vocab-size:1 num-oods:204 (100%)
# 	2: "Embarked" CATEGORICAL num-nas:2 (0.224467%) has-dict vocab-size:4 zero-ood-items most-frequent:"S" 644 (72.4409%)
# 	7: "Sex" CATEGORICAL has-dict vocab-size:3 zero-ood-items most-frequent:"male" 577 (64.7587%)
# 	9: "Ticket_item" CATEGORICAL has-dict vocab-size:17 num-oods:46 (5.16274%) most-frequent:"NONE" 665 (74.6352%)
# 	10: "Ticket_number" CATEGORICAL has-dict vocab-size:9 num-oods:842 (94.5006%) most-frequent:"<OOD>" 842 (94.5006%)
# 	11: "__LABEL" CATEGORICAL integerized vocab-size:3 no-ood-item
#
# NUMERICAL: 5 (41.6667%)
# 	0: "Age" NUMERICAL num-nas:177 (19.8653%) mean:29.6991 min:0.42 max:80 sd:14.5163
# 	3: "Fare" NUMERICAL mean:32.2042 min:0 max:512.329 sd:49.6655
# 	5: "Parch" NUMERICAL mean:0.381594 min:0 max:6 sd:0.805605
# 	6: "Pclass" NUMERICAL mean:2.30864 min:1 max:3 sd:0.835602
# 	8: "SibSp" NUMERICAL mean:0.523008 min:0 max:8 sd:1.10212
#
# CATEGORICAL_SET: 1 (8.33333%)
# 	4: "Name" CATEGORICAL_SET has-dict vocab-size:86 num-oods:1932 (216.835%) most-frequent:"<OOD>" 1932 (216.835%)
#
# Terminology:
# 	nas: Number of non-available (i.e. missing) values.
# 	ood: Out of dictionary.
# 	manually-defined: Attribute whose type is manually defined by the user, i.e., the type was not automatically inferred.
# 	tokenized: The attribute value is obtained through tokenization.
# 	has-dict: The attribute is attached to a string dictionary e.g. a categorical attribute stored as a string.
# 	vocab-size: Number of unique values.
#
# I0000 00:00:1743111976.435995 18509509 kernel.cc:818] Configure learner
# W0000 00:00:1743111976.436108 18509509 gradient_boosted_trees.cc:1873] "goss_alpha" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111976.436110 18509509 gradient_boosted_trees.cc:1883] "goss_beta" set but "sampling_method" not equal to "GOSS".
# W0000 00:00:1743111976.436112 18509509 gradient_boosted_trees.cc:1897] "selective_gradient_boosting_ratio" set but "sampling_method" not equal to "SELGB".
# I0000 00:00:1743111976.436163 18509509 kernel.cc:831] Training config:
# learner: "GRADIENT_BOOSTED_TREES"
# features: "^Age$"
# features: "^Cabin$"
# features: "^Embarked$"
# features: "^Fare$"
# features: "^Name$"
# features: "^Parch$"
# features: "^Pclass$"
# features: "^Sex$"
# features: "^SibSp$"
# features: "^Ticket_item$"
# features: "^Ticket_number$"
# label: "^__LABEL$"
# task: CLASSIFICATION
# random_seed: 199
# metadata {
#   framework: "TF Keras"
# }
# pure_serving_model: false
# [yggdrasil_decision_forests.model.gradient_boosted_trees.proto.gradient_boosted_trees_config] {
#   num_trees: 300
#   decision_tree {
#     max_depth: 6
#     min_examples: 5
#     in_split_min_examples_check: true
#     keep_non_leaf_label_distribution: true
#     num_candidate_attributes: -1
#     missing_value_policy: GLOBAL_IMPUTATION
#     allow_na_conditions: false
#     categorical_set_greedy_forward {
#       sampling: 0.1
#       max_num_items: -1
#       min_item_frequency: 1
#     }
#     growing_strategy_local {
#     }
#     categorical {
#       cart {
#       }
#     }
#     axis_aligned_split {
#     }
#     internal {
#       sorting_strategy: PRESORTED
#     }
#     uplift {
#       min_examples_in_treatment: 5
#       split_score: KULLBACK_LEIBLER
#     }
#     honest {
#       ratio_leaf_examples: 0.5
#       fixed_separation: false
#     }
#     numerical_vector_sequence {
#       max_num_test_examples: 1000
#       num_random_selected_anchors: 100
#     }
#   }
#   shrinkage: 0.1
#   loss: DEFAULT
#   validation_set_ratio: 0.1
#   validation_interval_in_trees: 1
#   early_stopping: VALIDATION_LOSS_INCREASE
#   early_stopping_num_trees_look_ahead: 30
#   l2_regularization: 0
#   lambda_loss: 1
#   mart {
#   }
#   adapt_subsample_for_maximum_training_duration: false
#   l1_regularization: 0
#   use_hessian_gain: false
#   l2_regularization_categorical: 1
#   xe_ndcg {
#     ndcg_truncation: 5
#   }
#   stochastic_gradient_boosting {
#     ratio: 1
#   }
#   apply_link_function: true
#   compute_permutation_variable_importance: false
#   early_stopping_initial_iteration: 10
# }
#
# I0000 00:00:1743111976.436187 18509509 kernel.cc:834] Deployment config:
# cache_path: "/var/folders/hc/xs3_7cjx0vg7ssqh_cxmkll00000gn/T/tmpbpygim_o/working_cache"
# num_threads: 11
# try_resume_training: true
#
# I0000 00:00:1743111976.436220 18986858 kernel.cc:895] Train model
# I0000 00:00:1743111976.436255 18986858 gradient_boosted_trees.cc:577] Default loss set to BINOMIAL_LOG_LIKELIHOOD
# I0000 00:00:1743111976.436260 18986858 gradient_boosted_trees.cc:1190] Training gradient boosted tree on 891 example(s) and 11 feature(s).
# I0000 00:00:1743111976.436455 18986858 gradient_boosted_trees.cc:1230] 788 examples used for training and 103 examples used for validation
# I0000 00:00:1743111976.436785 18986858 gpu.cc:93] Cannot initialize GPU: Not compiled with GPU support
# I0000 00:00:1743111976.439445 18986858 gradient_boosted_trees.cc:1632] Train tree 1/300 train-loss:1.232449 train-accuracy:0.624366 valid-loss:1.295408 valid-accuracy:0.553398 [total:0.00s iter:0.00s]
# I0000 00:00:1743111976.441769 18986858 gradient_boosted_trees.cc:1632] Train tree 2/300 train-loss:1.158678 train-accuracy:0.625634 valid-loss:1.215775 valid-accuracy:0.553398 [total:0.00s iter:0.00s]
# I0000 00:00:1743111976.520166 18986858 early_stopping.cc:54] Early stop of the training because the validation loss does not decrease anymore. Best valid-loss: 0.833943
# I0000 00:00:1743111976.520173 18986858 gradient_boosted_trees.cc:1669] Create final snapshot of the model at iteration 65
# I0000 00:00:1743111976.521297 18986858 gradient_boosted_trees.cc:279] Truncates the model to 36 tree(s) i.e. 36  iteration(s).
# I0000 00:00:1743111976.521533 18986858 gradient_boosted_trees.cc:341] Final model num-trees:36 valid-loss:0.833943 valid-accuracy:0.815534
# I0000 00:00:1743111976.521899 18986858 kernel.cc:926] Export model in log directory: /var/folders/hc/xs3_7cjx0vg7ssqh_cxmkll00000gn/T/tmpbpygim_o with prefix b5d0d21c00e340e3
# I0000 00:00:1743111976.522649 18986858 kernel.cc:944] Save model in resources
# I0000 00:00:1743111976.523181 18509509 abstract_model.cc:921] Model self evaluation:
# Task: CLASSIFICATION
# Label: __LABEL
# Loss (BINOMIAL_LOG_LIKELIHOOD): 0.833943
#
# Accuracy: 0.815534  CI95[W][0 1]
# ErrorRate: : 0.184466
#
#
# Confusion Table:
# truth\prediction
#     1   2
# 1  51   6
# 2  13  33
# Total: 103
#
#
# 2025-03-27 17:46:16.527433: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1206] Loading model from path /var/folders/hc/xs3_7cjx0vg7ssqh_cxmkll00000gn/T/tmpbpygim_o/model/ with prefix b5d0d21c00e340e3
# 2025-03-27 17:46:16.529020: I tensorflow_decision_forests/tensorflow/ops/inference/kernel.cc:1035] Use fast generic engine

# %%
kaggle_predictions.to_csv('submission.csv', index=False)
